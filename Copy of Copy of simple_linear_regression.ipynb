# %% [markdown]
# Data Science and Business Analytics intern at The Sparks Foundation
#
# Batch: January 2021
#
# Task 1: Prediction using Supervised ML
# Predict the percentage of a student based on the no. of study hours.
#
# Submitted by: Ekveera Joshi

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
files.download('https://colab.research.google.com/drive/17QQq_PWDS7b_lFUv4W-Gn0tHq5UQvCSv#scrollTo=QldetOPcmLk7')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-5ed59d100375> in <module>()
#       1 from google.colab import files
# ----> 2 files.download('https://colab.research.google.com/drive/17QQq_PWDS7b_lFUv4W-Gn0tHq5UQvCSv#scrollTo=QldetOPcmLk7')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     141       raise OSError(msg)
#     142     else:
# --> 143       raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     144
#     145   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: https://colab.research.google.com/drive/17QQq_PWDS7b_lFUv4W-Gn0tHq5UQvCSv#scrollTo=QldetOPcmLk7

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('student_scores - student_scores.csv')
#independent data variable 'x' (study hours) which helps determine the score.
x = dataset.iloc[:,:-1].values
#dependent variable(score)
y = dataset.iloc[:,-1].values

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# ## Training the Simple Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred=regressor.predict(x_test)

# %% [markdown]
# ## Visualising the Training set results

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('Scores predicted acc to the no. of study hours')
plt.xlabel('Study hours')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ## Visualising the Test set results

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_test),color='blue')#training and test line is the same, we just need to check how close are the values to the best-fitted line
plt.title('Scores predicted according to the no. of study hours/day')
plt.xlabel('Study hours/day')
plt.ylabel('Scores')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-667bb81d04b0> in <module>()
#       1 plt.scatter(x_test,y_test,color='red')
# ----> 2 plt.plot(x_train,regressor.predict(x_test),color='blue')#training and test line is the same, we just need to check how close are the values to the best-fitted line
#       3 plt.title('Scores predicted according to the no. of study hours/day')
#       4 plt.xlabel('Study hours/day')
#       5 plt.ylabel('Scores')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %% [markdown]
# Predicting scores if a student studies for 9.25 hrs/ day

# %%
print(regressor.predict([[9.25]]))#predict method takes 2D array as the format of the input
# Out:
# [93.69173249]

# %% [markdown]
# Getting the final linear regression with the values of coefficients

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [9.91065648]
# 2.018160041434662

# %% [markdown]
# Conclusion:

# %% [markdown]
# The predicted score of a student who invests 9.25 hours/day in studies is: 93.69
